# %% [markdown]
# IDS706_DataEngineering_BarbaraFlores_Project1
# ## 🤖 Continuous Integration using GitHub Actions of Python Data Science Project
#
# ### 🔍 Dataset:
# For this asigment, we will use the [LinkedInTechJobsDataset.csv](LinkedInTechJobsDataset.csv)
#
# The [LinkedInTechJobsDataset.csv](LinkedInTechJobsDataset.csv) is a comprehensive collection of job listings and related information sourced from LinkedIn, one of the world's leading professional networking platforms.
#
# This dataset provides valuable insights into job opportunities, job market trends, and various attributes associated with job listings .

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
from lib import mean_variable, median_variable, count_variable

# %% [markdown]
# ### 📊 Results
# We can calculate some descriptive statistics such as the mean, median, and total number of records for the following variables:
#
# - "Total_applicants"
# - "Employee_count"
# - "LinkedIn_Followers""

# %%
variable_list = ["Total_applicants", "Employee_count", "LinkedIn_Followers"]
path = '../data/LinkedInTechJobsDataset.csv'

print(" \nSome descriptive statistics: \n")
for i in variable_list:
    print(
        f"The mean of {i} is {round(mean_variable(path, i))}.")
    print(
        f"The median of {i} is {round(median_variable(path, i))}.")
    print(
        f"The count of {i} is {round(count_variable(path, i))}. \n")
# Out:
#
# Some descriptive statistics:
#
# The mean of Total_applicants is 23.
# The median of Total_applicants is 8.
# The count of Total_applicants is 811.
#
# The mean of Employee_count is 5178.
# The median of Employee_count is 5000.
# The count of Employee_count is 811.
#
# The mean of LinkedIn_Followers is 1401891.
# The median of LinkedIn_Followers is 270280.
# The count of LinkedIn_Followers is 811.

# %% [markdown]
# "However, measures of central tendency often conceal the true distribution of the sample,
# so it is interesting to observe a histogram of the same values."

# %%
df = pd.read_csv(path) 
variable = "Total_applicants"
plt.hist(df[[variable]], bins=10,)
plt.xlabel(variable)
plt.ylabel('frequency')
plt.title('Histogram of {0} per job posting'.format(variable))
plt.show()
plt.clf()

# %%
variable = "Employee_count"
plt.hist(df[[variable]], bins=10,)
plt.xlabel(variable)
plt.ylabel('frequency')
plt.title('Histogram of {0} per job posting'.format(variable))
plt.show()
plt.clf()

# %%
variable = "LinkedIn_Followers"
plt.hist(df[[variable]], bins=10,)
plt.xlabel(variable)
plt.ylabel('frequency')
plt.title('Histogram of {0} per job posting'.format(variable))
plt.show()
plt.clf()
